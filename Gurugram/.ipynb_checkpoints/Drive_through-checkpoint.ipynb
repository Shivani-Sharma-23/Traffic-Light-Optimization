# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import folium
import openrouteservice
from openrouteservice import convert
import math
import pandas as pd
import numpy as np
import decimal
from datetime import datetime, timedelta
import time
import matplotlib.pyplot as plt
import requests
from IPython.display import display, clear_output
import random

# %%
file_path = "gurugram_data.csv"
data = pd.read_csv(file_path)

# %%
data.columns
# Out:
# Index(['id', 'latitude', 'longitude', 'nearest_node', 'degree'], dtype='object')

# %%
data.head()
# Out:
#      id   latitude  longitude  nearest_node  degree
# 0  node  28.461697  77.087018     249350111       4
# 1  node  28.536270  77.197371     250078367       4
# 2  node  28.450043  77.063861    9903240504       4
# 3  node  28.482711  77.107530     251691410       3
# 4  node  28.491757  77.090856    5228569733       3

# %%
x , y  = data['latitude'] , data['longitude']

plt.scatter(x, y)
plt.show()

# %%
coords_path = [[lon, lat] for lon, lat in zip(data['longitude'], data['latitude'])]
n = folium.Map(location=list(reversed([77.09, 28.5])), tiles="cartodbpositron", zoom_start=12)
for coord in coords_path:
    folium.Marker(location=list(reversed(coord))).add_to(n)
n
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8070d17580fd9c025b34788de9389b1b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8070d17580fd9c025b34788de9389b1b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8070d17580fd9c025b34788de9389b1b = L.map(
#                 &quot;map_8070d17580fd9c025b34788de9389b1b&quot;,
#                 {
#                     center: [28.5, 77.09],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4853be496425bc36823fc4c4488d5aa4 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4853be496425bc36823fc4c4488d5aa4.addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_46dabef3b778e9944b5eab17f4d7169a = L.marker(
#                 [28.4616968, 77.0870179],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_63cf5affdc7258c218f16db8cefb0c8b = L.marker(
#                 [28.5362704, 77.1973711],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_714a10709211a6324e452fe07047bcfb = L.marker(
#                 [28.4500434, 77.063861],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_48297512e806de328f649494a85cef3e = L.marker(
#                 [28.4827111, 77.1075305],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_a8c6e96a77641bfc43f149e4406b9b9b = L.marker(
#                 [28.4917574, 77.0908564],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_7ee6e5f7f11b33d3f21bda8b6092c67c = L.marker(
#                 [28.436978, 77.0672279],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_d1cf0816a0772aeb82da784dd54e5f98 = L.marker(
#                 [28.4277636, 77.0583262],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_5929410d42022d4ec1f8c93109521b98 = L.marker(
#                 [28.5247292, 77.155435],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_4b075a831d7632a1db59a46cb9fec63f = L.marker(
#                 [28.5289358, 77.1483078],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_6d5c22d1881b36abd5f1a5879743e7a5 = L.marker(
#                 [28.467868, 77.0729926],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_9df091db7013b810922c4366b35eb1ba = L.marker(
#                 [28.4678722, 77.0731704],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_1a840fbbf1cb5c0a4505e5c6ca1f9155 = L.marker(
#                 [28.4596789, 77.0317789],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_a4727595ffc7eb16fb906c267f3e27dd = L.marker(
#                 [28.5443455, 77.1783143],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_46e4aaa929d14848958d1ac1ef443ef3 = L.marker(
#                 [28.5276395, 77.1890782],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_a1e55127db58fcd2cb26e651cd9d7c2c = L.marker(
#                 [28.511296, 77.1827517],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_8474c258ee3f301c709f466bfdda131e = L.marker(
#                 [28.5080584, 77.1771335],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_c3934fc06a412677ec3bf3c404673668 = L.marker(
#                 [28.4597303, 77.0316838],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_e0764282b629527a739e481a44f94e1d = L.marker(
#                 [28.458669, 77.0740437],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_5ab06fb15d9aa9b72aea0d5e15ae40ed = L.marker(
#                 [28.4595952, 77.049618],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);
#
#
#             var marker_0b87c3360c541b416ea012ac8581b83d = L.marker(
#                 [28.4679098, 77.1078588],
#                 {}
#             ).addTo(map_8070d17580fd9c025b34788de9389b1b);

# %%
degree_counts = data['degree'].value_counts()

plt.bar(degree_counts.index, degree_counts.values)
plt.xlabel('Degree')
plt.ylabel('Frequency')
plt.title('Frequency of Degree Values')
plt.xticks(degree_counts.index)

plt.show()

# %%
filtered_df = data[data['degree'].isin([5, 6, 8])]
filtered_df
# Out:
#        id   latitude  longitude  nearest_node  degree
# 17   node  28.458669  77.074044    9501049071       5
# 24   node  28.585618  77.146488    9794116732       6
# 30   node  28.575097  77.168516     282138885       6
# 41   node  28.597626  77.146186   11780481158       5
# 42   node  28.597724  77.146207   11780481159       6
# ..    ...        ...        ...           ...     ...
# 341  node  28.450235  77.069544    9903465142       6
# 342  node  28.449102  77.071824    3204210851       6
# 343  node  28.449283  77.071733    9903465132       6
# 344  node  28.449296  77.071866    9903465132       6
# 345  node  28.449789  77.086131    6092456732       8
#
# [86 rows x 5 columns]

# %%
map_center = [filtered_df['latitude'].mean(), filtered_df['longitude'].mean()]
m = folium.Map(location=map_center, zoom_start=12)

for idx, row in filtered_df.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"Node ID: {row['id']}<br>Degree: {row['degree']}",
        icon=folium.Icon(color='red' if row['degree'] == 8 else 'orange' if row['degree'] == 6 else 'blue')
    ).add_to(m)

m.save('map.html')

# Display map in a Jupyter notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68056bb42e9e826e8dd14665c7b240d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68056bb42e9e826e8dd14665c7b240d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_68056bb42e9e826e8dd14665c7b240d1 = L.map(
#                 &quot;map_68056bb42e9e826e8dd14665c7b240d1&quot;,
#                 {
#                     center: [28.510891498837207, 77.12498446860465],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9c2bd1da22e1827b7c095bf4584d689 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f9c2bd1da22e1827b7c095bf4584d689.addTo(map_68056bb42e9e826e8dd14665c7b240d1);
#
#
#             var marker_09b444c6405bac281ded2184ab31c0f5 = L.marker(
#                 [28.458669, 77.0740437],
#                 {}
#             ).addTo(map_68056bb42e9e826e8dd14665c7b240d1);
#
#
#             var icon_24bdda2f4f7daf5b03436609c00ead33 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_09b444c6405bac281ded2184ab31c0f5.setIcon(icon_24bdda2f4f7daf5b03436609c00ead33);
#
#
#         var popup_a46f6db841b07c657303bec5221ccf18 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6c219bf0ac5411ac601d9b9d9547739e = $(`&lt;div id=&quot;html_6c219bf0ac5411ac601d9b9d9547739e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Node ID: node&lt;br&gt;Degree: 5&lt;/div&gt;`)[0];
#                 popup_a46f6db841b07c657303bec5221ccf18.setContent(html_6c219bf0ac5411ac601d9b9d9547739e);
#
#
#
#         marker_09b444c6405bac281ded2184ab31c0f5.bindPopup(popup_a46f6db841b07c657303bec5221ccf18)
#         ;
#
#
#
#
#             var marker_26b0b6878064a2015f6e2fee573b72fc = L.marker(
#                 [28.585618, 77.1464877],
#                 {}
#             ).addTo(map_68056bb42e9e826e8dd14665c7b240d1);
#
#
#             var icon_ced3fe92cce875921af88eaf6422afd9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_26b0b6878064a2015f6e2fee573b72fc.setIcon(icon_ced3fe92cce875921af88eaf6422afd9);
#
#
#         var popup_2d12bed69ceea3b8e320619e6a895582 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fdc69f43a34aec5e708c1bb6d9df3bfd = $(`&lt;div id=&quot;html_fdc69f43a34aec5e708c1bb6d9df3bfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Node ID: node&lt;br&gt;Degree: 6&lt;/div&gt;`)[0];
#                 popup_2d12bed69ceea3b8e320619e6a895582.setContent(html_fdc69f43a34aec5e708c1bb6d9df3bfd);
#
#
#
#         marker_26b0b6878064a2015f6e2fee573b72fc.bindPopup(popup_2d12bed69ceea3b8e320619e6a895582)
#         ;
#
#
#
#
#             var marker_94c20209286f2fb4d34a006507b45558 = L.marker(
#                 [28.5750969, 77.1685162],
#                 {}
#             ).addTo(map_68056bb42e9e826e8dd14665c7b240d1);
#
#
#             var icon_da3fa55357cef7b14e2e6ad6e27ab478 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_94c20209286f2fb4d34a006507b45558.setIcon(icon_da3fa55357cef7b14e2e6ad6e27ab478);
#
#
#         var popup_54bfc5f9a2bde646b205d5512796992b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_86b44c791259226705367028eb6985aa = $(`&lt;div id=&quot;html_86b44c791259226705367028eb6985aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Node ID: node&lt;br&gt;Degree: 6&lt;/div&gt;`)[0];
#                 popup_54bfc5f9a2bde646b205d5512796992b.setContent(html_86b44c791259226705367028eb6985aa);
#
#
#
#         marker_94c20209286f2fb4d34a006507b45558.bindPopup(popup_54bfc5f9a2bde646b205d5512796992b)
#         ;
#
#
#
#
#             var marker_56c2c7a999ebbd62a57ab888ee94b5f5 = L.marker(
#                 [28.5976262, 77.1461863],
#                 {}
#             ).addTo(map_68056bb42e9e826e8dd14665c7b240d1);
#
#
#             var icon_a61fc0143acf2f2db061787083c8f0d0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &qu

# %%
client = openrouteservice.Client(key='5b3ce3597851110001cf62487dab724e881e4bfeab36d60cd37e61f6')

def get_address(row):
    try:
        coordinates = (row['longitude'], row['latitude'])
        result = client.pelias_reverse(point=coordinates)
        address = result['features'][0]['properties']['label']
        return address
    except Exception as e:
        return str(e)

data['address'] = data.apply(get_address, axis=1)

print("Addresses have been added to the dataset.")
# Out:
# Addresses have been added to the dataset.

# %%
data
# Out:
#        id   latitude  longitude  nearest_node  degree  \
# 0    node  28.461697  77.087018     249350111       4
# 1    node  28.536270  77.197371     250078367       4
# 2    node  28.450043  77.063861    9903240504       4
# 3    node  28.482711  77.107530     251691410       3
# 4    node  28.491757  77.090856    5228569733       3
# ..    ...        ...        ...           ...     ...
# 350  node  28.458890  77.073936     266595943       4
# 351  node  28.471020  77.072484    1987622348       4
# 352  node  28.498291  77.088351    4135550240       4
# 353  node  28.471079  77.072706    6112563505       3
# 354  node  28.470875  77.072556    1987622324       4
#
#                                          address
# 0         Guardian Pharmacy, Gurugram, HR, India
# 1          Krishna Super Marché 37, Delhi, India
# 2                Vista Wood, Gurugram, HR, India
# 3             Moulsari Road, Gurugram, HR, India
# 4    Royal Bank of Scotland, Gurugram, HR, India
# ..                                           ...
# 350      August Kranti Marg, Gurugram, HR, India
# 351      August Kranti Marg, Gurugram, HR, India
# 352          DLF Cyber City, Gurugram, HR, India
# 353      August Kranti Marg, Gurugram, HR, India
# 354      August Kranti Marg, Gurugram, HR, India
#
# [355 rows x 6 columns]

# %%
min_latitude = 28.4291
max_latitude = 28.4592
min_longitude = 77.0367
max_longitude = 77.0725

# Filter the rows within the bounding box
path_points = data[
    (data['latitude'] >= min_latitude) &
    (data['latitude'] <= max_latitude) &
    (data['longitude'] >= min_longitude) &
    (data['longitude'] <= max_longitude)
]

# %%
coords_path = [[lon, lat] for lon, lat in zip(path_points['longitude'], path_points['latitude'])]
n = folium.Map(location=list(reversed([77.049466, 28.808122])), tiles="cartodbpositron", zoom_start=12)
for coord in coords_path:
    folium.Marker(location=list(reversed(coord))).add_to(n)
n
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1aaf3ebc1828ccb6278bd96a15bbba0f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1aaf3ebc1828ccb6278bd96a15bbba0f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1aaf3ebc1828ccb6278bd96a15bbba0f = L.map(
#                 &quot;map_1aaf3ebc1828ccb6278bd96a15bbba0f&quot;,
#                 {
#                     center: [28.808122, 77.049466],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e54184d816088fe29d57c9fd5be886d6 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e54184d816088fe29d57c9fd5be886d6.addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_fa96442792c36aee41952312856b1c7d = L.marker(
#                 [28.4500434, 77.063861],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_ec693024a4ffddfec88ec8567e429afc = L.marker(
#                 [28.436978, 77.0672279],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_3bbe1fb90026796054596119cf0f4282 = L.marker(
#                 [28.452188, 77.0416024],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_cf0e7e2e3b757c13eeef92e88d39c4a1 = L.marker(
#                 [28.4516299, 77.0420417],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_9a971a2ba0e6cc2130868845b2502a04 = L.marker(
#                 [28.4517923, 77.0421067],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_c14708381bd0b20aa3dd5f1a65438026 = L.marker(
#                 [28.4520118, 77.0415582],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_52213289e08d6b41c4f5911176bc3b17 = L.marker(
#                 [28.4464157, 77.0477058],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_57263878e2a8425b1e90aa4e35e2ee11 = L.marker(
#                 [28.4501386, 77.0693952],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_42282faefeaa8e4135b856e8897a1f23 = L.marker(
#                 [28.4524982, 77.0665591],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_b7c440dae85250617e4b81b932923cac = L.marker(
#                 [28.4500776, 77.0694793],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_8ffefb2d11dc1859d7bd696ab7ed5346 = L.marker(
#                 [28.4502654, 77.0694145],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_4d9b91e355b0ed9dd2406ef721332f47 = L.marker(
#                 [28.4502352, 77.0695441],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_fe446e37a3df23e302e6fe158fc2215b = L.marker(
#                 [28.449102, 77.0718244],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_aa3d70adcef7a3d8073c5ffd31476ffb = L.marker(
#                 [28.4492831, 77.0717328],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_17171183db014342c2cad686f4b9ad77 = L.marker(
#                 [28.4492965, 77.0718663],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_6db527955994a712e56b193992916a41 = L.marker(
#                 [28.452433, 77.0663011],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_bf95234d25111ef9b2bacd7181acbf35 = L.marker(
#                 [28.4523382, 77.0664919],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_b5d216715f6d6e64718a6b59ecef1257 = L.marker(
#                 [28.4500434, 77.063861],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_c3ecebc6d676f3de97a281d0dfc92ae8 = L.marker(
#                 [28.436978, 77.0672279],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);
#
#
#             var marker_1be480ae1647449f79cd22f88e6632ef = L.marker(
#                 [28.452188, 77.0416024],
#                 {}
#             ).addTo(map_1aaf3ebc1828ccb6278bd96a15bbba0f);

# %%
api_key = '5b3ce3597851110001cf62487dab724e881e4bfeab36d60cd37e61f6'
client = openrouteservice.Client(key=api_key)

start_coords = (28.4291, 77.0984433)
end_coords = (28.4592, 77.049466)

route = client.directions(coordinates=[(start_coords[1], start_coords[0]), (end_coords[1], end_coords[0])], profile='driving-car', format='geojson')
route_coords = [(coord[1], coord[0]) for coord in route['features'][0]['geometry']['coordinates']]
car_map = folium.Map(location=[start_coords[0], start_coords[1]], zoom_start=14)
folium.GeoJson(route, name='route').add_to(car_map)

folium.Marker(
    location=[start_coords[0], start_coords[1]],
    popup='Start',
    icon=folium.Icon(color='green')
).add_to(car_map)

folium.Marker(
    location=[end_coords[0], end_coords[1]],
    popup='End',
    icon=folium.Icon(color='red')
).add_to(car_map)
coords_path = [[lon, lat] for lon, lat in zip(path_points['longitude'], path_points['latitude'])]

distance = route['features'][0]['properties']['segments'][0]['distance'] / 1000
duration = route['features'][0]['properties']['segments'][0]['duration'] / 60

folium.map.Marker(
    [start_coords[0], start_coords[1]],
    icon=folium.DivIcon(
        html=f'<div style="font-size: 16pt">Distance: {distance:.2f} km<br>Duration: {duration:.2f} min</div>'
    )
).add_to(car_map)


car_map.save('car_movement_directions_map.html')

display(car_map)


for i in range(len(route_coords)):
    current_coords = route_coords[i]
    clear_output(wait=True)
    car_map = folium.Map(location=current_coords, zoom_start=14)
    folium.GeoJson(route, name='route').add_to(car_map)
    folium.Marker(
        location=[start_coords[0], start_coords[1]],
        popup='Start',
        icon=folium.Icon(color='green')
    ).add_to(car_map)

    folium.Marker(
        location=[end_coords[0], end_coords[1]],
        popup='End',
        icon=folium.Icon(color='red')
    ).add_to(car_map)

    folium.PolyLine(locations=route_coords[:i+1], color='blue').add_to(car_map)

    speed_limit = random.uniform(50, 52)

    print(f'Current speed limit: {speed_limit:.2f} km/h')

    folium.Marker(
        location=current_coords,
        popup=f'Speed Limit: {speed_limit:.2f} km/h',
        icon=folium.Icon(color='red')
    ).add_to(car_map)

    # Display the map
    display(car_map)

    time.sleep(0.1)
# Out:
# Current speed limit: 50.14 km/h
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_df67ed4a6f740e01e6b4286871b5b7db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_df67ed4a6f740e01e6b4286871b5b7db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_df67ed4a6f740e01e6b4286871b5b7db = L.map(
#                 &quot;map_df67ed4a6f740e01e6b4286871b5b7db&quot;,
#                 {
#                     center: [28.459222, 77.049468],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40f68b99c0de8cf9254695b910ea6d99 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_40f68b99c0de8cf9254695b910ea6d99.addTo(map_df67ed4a6f740e01e6b4286871b5b7db);
#
#
#
#         function geo_json_242d65b2ea86c16b08934b4eca91a96f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_242d65b2ea86c16b08934b4eca91a96f = L.geoJson(null, {
#                 onEachFeature: geo_json_242d65b2ea86c16b08934b4eca91a96f_onEachFeature,
#
#         });
#
#         function geo_json_242d65b2ea86c16b08934b4eca91a96f_add (data) {
#             geo_json_242d65b2ea86c16b08934b4eca91a96f
#                 .addData(data);
#         }
, 8]}, {&quot;distance&quot;: 2359.8, &quot;duration&quot;: 141.6, &quot;instruction&quot;: &quot;Turn right&quot;, &quot;name&quot;: &quot;-&quot;, &quot;type&quot;: 1, &quot;way_points&quot;: [8, 35]}, {&quot;distance&quot;: 381.8, &quot;duration&quot;: 34.4, &quot;instruction&quot;: &quot;Turn left onto Sector Road&quot;, &quot;name&quot;: &quot;Sector Road&quot;, &quot;type&quot;: 0, &quot;way_points&quot;: [35, 43]}, {&quot;distance&quot;: 1128.9, &quot;duration&quot;: 85.4, &quot;instr

# %%
import folium
import openrouteservice
import random
import time
from IPython.display import display, clear_output

# Initialize OpenRouteService client
api_key = '5b3ce3597851110001cf62487dab724e881e4bfeab36d60cd37e61f6'
client = openrouteservice.Client(key=api_key)

# Define start and end coordinates
start_coords = (28.4291, 77.0984433)
end_coords = (28.4592, 77.049466)

# Get the route
route = client.directions(
    coordinates=[(start_coords[1], start_coords[0]), (end_coords[1], end_coords[0])],
    profile='driving-car',
    format='geojson'
)

# Extract route coordinates
route_coords = [(coord[1], coord[0]) for coord in route['features'][0]['geometry']['coordinates']]

# Initialize folium map
car_map = folium.Map(location=[start_coords[0], start_coords[1]], zoom_start=14)
folium.GeoJson(route, name='route').add_to(car_map)

# Add start and end markers
folium.Marker(
    location=[start_coords[0], start_coords[1]],
    popup='Start',
    icon=folium.Icon(color='green')
).add_to(car_map)

folium.Marker(
    location=[end_coords[0], end_coords[1]],
    popup='End',
    icon=folium.Icon(color='red')
).add_to(car_map)

# Add path points markers (with blue color)
for idx, row in path_points.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f'Point {idx}',
        icon=folium.Icon(color='blue')
    ).add_to(car_map)

# Add distance and duration info
distance = route['features'][0]['properties']['segments'][0]['distance'] / 1000
duration = route['features'][0]['properties']['segments'][0]['duration'] / 60

folium.map.Marker(
    [start_coords[0], start_coords[1]],
    icon=folium.DivIcon(
        html=f'<div style="font-size: 16pt">Distance: {distance:.2f} km<br>Duration: {duration:.2f} min</div>'
    )
).add_to(car_map)

# Save the initial map as an HTML file
car_map.save('car_movement_directions_map.html')

# Display the initial map
display(car_map)

# Animate the car movement along the route
for i, current_coords in enumerate(route_coords):
    clear_output(wait=True)
    car_map = folium.Map(location=current_coords, zoom_start=14)
    folium.GeoJson(route, name='route').add_to(car_map)
    folium.Marker(
        location=[start_coords[0], start_coords[1]],
        popup='Start',
        icon=folium.Icon(color='green')
    ).add_to(car_map)

    folium.Marker(
        location=[end_coords[0], end_coords[1]],
        popup='End',
        icon=folium.Icon(color='red')
    ).add_to(car_map)

    folium.PolyLine(locations=route_coords[:i + 1], color='blue').add_to(car_map)

    # Add path points markers again
    for idx, row in path_points.iterrows():
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=f'Point {idx}',
            icon=folium.Icon(color='blue')
        ).add_to(car_map)

    # Add speed limit (randomly generated for demonstration)
    speed_limit = random.uniform(50, 52)
    folium.Marker(
        location=current_coords,
        popup=f'Speed Limit: {speed_limit:.2f} km/h',
        icon=folium.Icon(color='red')
    ).add_to(car_map)

    # Display the current frame (optional)
    display(car_map)
    time.sleep(0.1)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0
[77.050305, 28.459067], [77.050213, 28.459136], [77.05017, 28.459169], [77.050007, 28.459297], [77.049789, 28.459167], [77.049568, 28.459215], [77.049468, 28.459222]], &quot;type&quot;: &quot;LineString&quot;}, &quot;properties&quot;: {&quot;segments&quot;: [{&quot;distance&quot;: 7013.8, &quot;duration&quot;: 586.9, &quot;steps&quot;: [{&quot;distance&quot;: 381.8, &quot;duration&quot;: 91.6, &quot;instruction&quot;: &quot;Head west&quot;, &quot;name&quot;: &quot;-&quot;, &quot;type&quot;: 11, &quot;way_points&quot;: [0, 2]}, {&quot;distance&quot;: 206.5, &quot;duration&quot;: 16.5, &quot;instruction&quot;: &quot;Turn right&quot;, &quot;name&quot;: &quot;-&quot;, &quot;type&quot;: 1, &quot;way_points&quot;: [2, 4]}, {&quot;distance&quot;: 350.5, &quot;duration&quot;: 33.7, &quot;instruction&quot;: &quot;Turn sharp left&quot;, &quot;name&quot;: &quot;-&quot;, &quot;type&quot;: 2, &quot;way_points&quot;: [4, 8]}, {&quot;distance&quot;: 2359.8, &quot;duration&quot;: 141.6, &quot;instruction&quot;: &quot;Turn right&quot;, &quot;name&quot;: &quot;-&quot;, &quot;type&quot;: 1, &quot;way_points&quot;: [8, 35]}, {&quot;distance&quot;: 381.8, &quot;duration&quot;: 34.4, &quot;instruction&quot;: &quot;Turn left onto Sector Road&quot;, &quot;name&quot;: &quot;Sector Road&quot;, &quot;type&quot;: 0, &quot;way_points&quot;: [35, 43]}, {&quot;distance&quot;: 1128.9, &quot;duration&quot;: 85.4, &quot;instr

# %%
import folium
import openrouteservice
import random
import time
from IPython.display import display, clear_output
from geopy.distance import geodesic
import pandas as pd


# Initialize OpenRouteService client
api_key = '5b3ce3597851110001cf62487dab724e881e4bfeab36d60cd37e61f6'
client = openrouteservice.Client(key=api_key)

# Define start and end coordinates
start_coords = (28.4291, 77.0984433)
end_coords = (28.4592, 77.049466)

# Get the route
route = client.directions(
    coordinates=[(start_coords[1], start_coords[0]), (end_coords[1], end_coords[0])],
    profile='driving-car',
    format='geojson'
)

# Extract route coordinates
route_coords = [(coord[1], coord[0]) for coord in route['features'][0]['geometry']['coordinates']]

# Filter path_points that are near the route
def is_near_route(point, route_coords, threshold=0.5):
    """Check if a point is within the threshold distance (in km) of the route."""
    point_lat, point_lon = point
    for route_lat, route_lon in route_coords:
        if geodesic((point_lat, point_lon), (route_lat, route_lon)).km <= threshold:
            return True
    return False

# Threshold distance in km
threshold_distance = 0.5
filtered_path_points = data[
    data.apply(lambda row: is_near_route((row['latitude'], row['longitude']), route_coords, threshold_distance), axis=1)
]

# Initialize folium map
car_map = folium.Map(location=[start_coords[0], start_coords[1]], zoom_start=14)
folium.GeoJson(route, name='route').add_to(car_map)

# Add start and end markers
folium.Marker(
    location=[start_coords[0], start_coords[1]],
    popup='Start',
    icon=folium.Icon(color='green')
).add_to(car_map)

folium.Marker(
    location=[end_coords[0], end_coords[1]],
    popup='End',
    icon=folium.Icon(color='red')
).add_to(car_map)

# Add filtered path points markers (with blue color)
for idx, row in filtered_path_points.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f'Point {idx}',
        icon=folium.Icon(color='blue')
    ).add_to(car_map)

# Add distance and duration info
distance = route['features'][0]['properties']['segments'][0]['distance'] / 1000
duration = route['features'][0]['properties']['segments'][0]['duration'] / 60

folium.map.Marker(
    [start_coords[0], start_coords[1]],
    icon=folium.DivIcon(
        html=f'<div style="font-size: 16pt">Distance: {distance:.2f} km<br>Duration: {duration:.2f} min</div>'
    )
).add_to(car_map)

# Save the initial map as an HTML file
car_map.save('car_movement_directions_map.html')

# Display the initial map
display(car_map)

# Animate the car movement along the route
for i, current_coords in enumerate(route_coords):
    clear_output(wait=True)
    car_map = folium.Map(location=current_coords, zoom_start=14)
    folium.GeoJson(route, name='route').add_to(car_map)
    folium.Marker(
        location=[start_coords[0], start_coords[1]],
        popup='Start',
        icon=folium.Icon(color='green')
    ).add_to(car_map)

    folium.Marker(
        location=[end_coords[0], end_coords[1]],
        popup='End',
        icon=folium.Icon(color='red')
    ).add_to(car_map)

    folium.PolyLine(locations=route_coords[:i + 1], color='blue').add_to(car_map)

    # Add filtered path points markers again
    for idx, row in filtered_path_points.iterrows():
        folium.Marker(
            location=[row['latitude'], row['longitude']],
            popup=f'Point {idx}',
            icon=folium.Icon(color='blue')
        ).add_to(car_map)

    # Add speed limit (randomly generated for demonstration)
    speed_limit = random.uniform(50, 52)
    folium.Marker(
        location=current_coords,
        popup=f'Speed Limit: {speed_limit:.2f} km/h',
        icon=folium.Icon(color='red')
    ).add_to(car_map)

    # Display the current frame (optional)
    display(car_map)
    time.sleep(0.1)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91453c4aff1efcae08e6302b123d6953 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91453c4aff1efcae08e6302b123d6953&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91453c4aff1efcae08e6302b123d6953 = L.map(
#                 &quot;map_91453c4aff1efcae08e6302b123d6953&quot;,
#                 {
#                     center: [28.459222, 77.049468],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 14,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36514b5600a64107a8443d4bb9786ad8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_36514b5600a64107a8443d4bb9786ad8.addTo(map_91453c4aff1efcae08e6302b123d6953);
#
#
#
#         function geo_json_f696c681a72c762f09d6a689075ec38f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_f696c681a72c762f09d6a689075ec38f = L.geoJson(null, {
#                 onEachFeature: geo_json_f696c681a72c762f09d6a689075ec38f_onEachFeature,
#
#         });
#
#         function geo_json_f696c681a72c762f09d6a689075ec38f_add (data) {
#             geo_json_f696c681a72c762f09d6a689075ec38f
#                 .addData(data);
#         }
#             geo_json_f696c681a72c762f09d6a689075ec38f_add({&quot;bbox&quot;: [77.049468, 28.429033, 77.098443, 28.459297], &quot;features&quot;: [{&quot;bbox&quot;: [77.049468, 28.429033, 77.098443, 28.459297], &quot;geometry&quot;: {&quot;coordinates&quot;: [[77.098443, 28.429033], [77.098051, 28.429035], [77.094538, 28.429055], [77.094567, 28.430778], [77.094573, 28.430911], [77.092916, 28.430433], [77.091834, 28.430078], [77.091338, 28.429902], [77.091189, 28.429882], [77.091187, 28.429973], [77.091164, 28.431058], [77.090979, 28.432258], [77.090923, 28.432549], [77.090864, 28.432907], [77.090606, 28.434392], [77.090359, 28.435952], [77.090205, 28.436715], [77.090145, 28.43691], [77.089951, 28.437502], [77.089684, 28.438021], [77.08937, 